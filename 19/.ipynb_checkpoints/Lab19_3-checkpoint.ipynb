# %% [markdown]
# # Реализация задания 3
#
# Заголовок со всякими импортами

# %%
import pandas as pd
import numpy as np
import scipy as sp
import chart_studio.plotly as py
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode

import ipywidgets as widgets
from ipywidgets import interact, interact_manual

from IPython.display import display, Math, Latex

init_notebook_mode(connected=True)
# number of terms in solving degree equation
_ELLIPDEG_MMAX = 7


def _ellipdeg(n, m1):
    """Solve degree equation using nomes

    Given n, m1, solve
       n * K(m) / K'(m) = K1(m1) / K1'(m1)
    for m
    
    NB: Uses squares of arguments!
    See [1], Eq. (49)
    
    References
    ----------
    .. [1] Orfanidis, "Lecture Notes on Elliptic Filter Design",
           https://www.ece.rutgers.edu/~orfanidi/ece521/notes.pdf
    """
    K1 = sp.special.ellipk(m1)
    K1p = sp.special.ellipkm1(m1)

    q1 = np.exp(-np.pi * K1p / K1)
    q = q1 ** (1/n)

    mnum = np.arange(_ELLIPDEG_MMAX + 1)
    mden = np.arange(1, _ELLIPDEG_MMAX + 2)

    num = np.sum(q ** (mnum * (mnum+1)))
    den = 1 + 2 * np.sum(q ** (mden**2))

    return 16 * q * (num / den) ** 4
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## 1. Общее представление
# Для "игр" с типами фильтров. Параметры такие:
# * `order` — порядок фильтра
# * `rp` — неравномерность (в дБ) для полосы пропускания (относится к фильтрам Чебышева и эллиптическим)
# * `rn` — максимальный уровень (в дБ) в полосе задержания (для эллиптического фильтра)

# %%
@interact(
    filter = widgets.Dropdown(options = [
        ("Butterworth", sp.signal.buttap),
        ("Chebyshev", sp.signal.cheb1ap),
        ("Elliptic", sp.signal.ellipap)]),
    plot = widgets.Dropdown(options = [
        ("Zeros & Poles", 0),
        ("Amplitude response", 1),
        ("Phase response", 2)
    ]),
    order = widgets.IntSlider(min = 1, max = 13, step = 1, value = 1),
    rp = widgets.FloatSlider(min = 1, max = 10, step = 0.1, value = 3),
    rs = widgets.FloatSlider(min = 20, max = 100, step = 0.1, value = 40),
)
def myplot(filter, plot, order, rp, rs):
    if filter == sp.signal.buttap:
        opts = {"N": order}
    elif filter == sp.signal.cheb1ap:
        opts = {"N": order, "rp": rp}
    elif filter == sp.signal.ellipap:
        opts = {"N": order, "rp": rp, "rs": rs}
    z, p, k = filter(**opts)
    w, h = sp.signal.freqs_zpk(z, p, k, worN = np.logspace(-1, 3, 1001))
    
    if plot == 0:
        fig = go.Figure(
            [
                go.Scatter(x = np.real(z), y = np.imag(z), mode = 'markers', name = f"Zeros {len(z)}"),
                go.Scatter(x = np.real(p), y = np.imag(p), mode = 'markers', name = f"Poles {len(p)}")
            ]
        )
        fig.update_yaxes(
            scaleanchor="x",
            scaleratio=1
        )
    elif plot == 1:
        fig = go.Figure(go.Scatter(x = w, y = 20*np.log10(np.abs(h)), mode = 'lines', name = "Transfer function"))
        fig.update_xaxes(type = "log")
    elif plot == 2:
        fig = go.Figure(go.Scatter(x = w, y = np.unwrap(np.angle(h, deg = True), period=180), mode = 'lines', name = "Transfer function"))
        fig.update_xaxes(type = "log")
    
    fig.show()
# Out:
# interactive(children=(Dropdown(description='filter', options=(('Butterworth', <function buttap at 0x7f2b26be81…

# %% [markdown]
# ## 2. Сравнение Чебышева и Баттерворта (при одном уровне)

# %%
w, h = sp.signal.freqs_zpk(*sp.signal.cheb1ap(N = 7, rp = 3.0), worN = 2.0)
Eta = 10**(1/(2*7) * np.log10(1/np.abs(h[0])**2 - 1))
# w, h = sp.signal.freqs_zpk(*sp.signal.buttap(N = 7), worN = Eta)
print(f"Fading for Chebyshev at Wn = 2.0: {20*np.log10(np.abs(h[0])):4.1f} dB")
print(f"Frequency for Butterworth(N = 7): {Eta:4.2f}")

w1, h1 = sp.signal.freqs_zpk(*sp.signal.cheb1ap(N = 7, rp = 3.0))
w2, h2 = sp.signal.freqs_zpk(*sp.signal.buttap(N = 7))
fig = go.Figure(
    [
        go.Scatter(x = w1, y = 20*np.log10(np.abs(h1)), name = "Chebyshev (N = 7, rp = 3 dB)"),
        go.Scatter(x = w2, y = 20*np.log10(np.abs(h2)), name = "Butterworth (N = 7)"),    
    ]
)
fig.add_vline(x = 2.0, line_dash = "dot")
fig.add_hline(y = 20*np.log10(np.abs(h[0])), line_dash = "dot")
fig.add_vline(x = Eta, line_dash = "dot", name = "Eta")
fig.show()
# Out:
# Fading for Chebyshev at Wn = 2.0: -74.0 dB
# Frequency for Butterworth(N = 7): 3.38
# <div>                            <div id="ee0df213-7389-4aff-8b20-99099df80193" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee0df213-7389-4aff-8b20-99099df80193")) {                    Plotly.newPlot(                        "ee0df213-7389-4aff-8b20-99099df80193",                        [{"name":"Chebyshev (N = 7, rp = 3 dB)","x":[0.01,0.010353218432956621,0.010718913192051276,0.011097524964120722,0.011489510001873092,0.011895340673703195,0.012315506032928256,0.012750512407130129,0.01320088400831418,0.013667163564620066,0.01414991297434576,0.014649713983072856,0.015167168884709226,0.015702901247293774,0.01625755666443794,0.016831803533309566,0.0174263338600965,0.018041864093920716,0.01867913599020783,0.01933891750455231,0.020022003718155844,0.02072921779595371,0.021461411978584036,0.02221946860939524,0.02300430119772918,0.023816855519761582,0.024658110758226028,0.025529080682395167,0.026430814869741057,0.027364399970746706,0.02833096101839324,0.02933166278390044,0.030367711180354574,0.031440354715915,0.032550885998350584,0.03370064329271928,0.034891012134067735,0.0361234269970943,0.03739937302478798,0.03872038781812555,0.04008806328898465,0.04150404757850477,0.04297004704320839,0.04448782831127585,0.04605922041145106,0.04768611697714469,0.049370478528390035,0.051114334834401656,0.05291978735958442,0.054789011795939424,0.05672426068491978,0.05872786613189483,0.06080224261649421,0.06294988990221888,0.06517339604882423,0.06747544053110693,0.0698587974678525,0.07232633896483534,0.07488103857590023,0.0775259748862946,0.08026433522257174,0.08309941949353396,0.086034644166845,0.0890735463861044,0.09221978823334327,0.09547716114208056,0.09884959046625587,0.10234114021054533,0.10595601792776159,0.10969857978923835,0.11357333583431052,0.11758495540521563,0.12173827277396614,0.12603829296797275,0.13049019780144022,0.13509935211980265,0.1398713102647238,0.14481182276745339,0.14992684327860456,0.15522253574270473,0.16070528182616384,0.16638168860761282,0.17225859653987866,0.17834308769319093,0.18464249428955434,0.19116440753857017,0.19791668678535562,0.2049074689815847,0.21214517849106299,0.21963853724165458,0.22739657523579276,0.23542864143224165,0.24374441501222205,0.2523539170434766,0.2612675225563328,0.27049597304631345,0.2800503894183631,0.28994228538828765,0.3001835813575589,0.31078661877820124,0.32176417502507354,0.3331294787934673,0.3448962260405758,0.35707859649004625,0.36969127071950264,0.3827494478516311,0.3962688638701478,0.41026581058271927,0.42475715525368984,0.4397603609302719,0.4552935074866948,0.4713753134116724,0.48802515836544313,0.505263106533568,0.5231099308056261,0.5415871378079471,0.5607169938205459,0.5805225516094898,0.6010276782070382,0.6222570836730228,0.644236350872137,0.6669919663030122,0.6905513520162327,0.7149428986597577,0.7401959996915641,0.7663410868007454,0.7934096665797492,0.8214343584919426,0.8504489341802677,0.880488358164346,0.9115888299750818,0.9437878277775381,0.9771241535346497,1.011637979766207,1.0473708979594498,1.0843659686896097,1.1226677735108135,1.162322468679852,1.2033778407775892,1.2458833642950082,1.289890261253308,1.3354515629298989,1.382622173764655,1.4314589375234785,1.4820207057988586,1.5343684089300116,1.5885651294280527,1.6446761779946628,1.7027691722258995,1.762914118095948,1.8251834943190424,1.8896523396912097,1.9563983435170629,2.0255019392306663,2.0970464013232326,2.171117945694503,2.247805833548725,2.327202478960407,2.4094035602395243,2.4945081352303164,2.5826187606826747,2.6738416158399465,2.7682866303920637,2.8660676169482504,2.9673024081888695,3.072112998861756,3.180625692794119,3.292971255097148,3.409285069746811,3.52970730273065,3.6543830709572545,3.7834626171319288,3.9171014908092565,4.0554607358408274,4.19870708444391,4.347013158125022 ...

# %% [markdown]
# ## 3. Сравнение Чебышева и Баттерворта (при одной частоте)

# %%
worN = 1.5
w, h = sp.signal.freqs_zpk(*sp.signal.cheb1ap(N = 7, rp = 3.0), worN = worN)
buttN = int(np.round(0.5*np.log10(1/np.abs(h[0])**2 - 1)/np.log10(worN)))
print(f"Fading for Chebyshev at Wn = 1.5: {20*np.log10(np.abs(h[0])):4.1f} dB")
print(f"Order of Butterworth: {buttN}")

w1, h1 = sp.signal.freqs_zpk(*sp.signal.cheb1ap(N = 7, rp = 3.0))
w2, h2 = sp.signal.freqs_zpk(*sp.signal.buttap(N = buttN))
fig = go.Figure(
    [
        go.Scatter(x = w1, y = 20*np.log10(np.abs(h1)), name = "Chebyshev (N = 7, rp = 3 dB)"),
        go.Scatter(x = w2, y = 20*np.log10(np.abs(h2)), name = f"Butterworth (N = {buttN})"),    
    ]
)
fig.add_vline(x = worN, line_dash = "dot")
fig.add_hline(y = 20*np.log10(np.abs(h[0])), line_dash = "dot")
fig.show()
# Out:
# Fading for Chebyshev at Wn = 1.5: -52.5 dB
# Order of Butterworth: 15
# <div>                            <div id="7f132d86-174a-4e66-b8c7-5150d0faaf02" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f132d86-174a-4e66-b8c7-5150d0faaf02")) {                    Plotly.newPlot(                        "7f132d86-174a-4e66-b8c7-5150d0faaf02",                        [{"name":"Chebyshev (N = 7, rp = 3 dB)","x":[0.01,0.010353218432956621,0.010718913192051276,0.011097524964120722,0.011489510001873092,0.011895340673703195,0.012315506032928256,0.012750512407130129,0.01320088400831418,0.013667163564620066,0.01414991297434576,0.014649713983072856,0.015167168884709226,0.015702901247293774,0.01625755666443794,0.016831803533309566,0.0174263338600965,0.018041864093920716,0.01867913599020783,0.01933891750455231,0.020022003718155844,0.02072921779595371,0.021461411978584036,0.02221946860939524,0.02300430119772918,0.023816855519761582,0.024658110758226028,0.025529080682395167,0.026430814869741057
    return 1/np.sqrt(_ellipdeg(7, 10**(-0.1*eta1)))

# %% [markdown]
# Уровень затухания эллиптического фильтра 7-го порядка с граничной частотой 1.1

# %%
rs = -ellip_stopband_level(7, 1.1)
print(f"Fade level = {rs:4.2f} dB")
# Out:
# Fade level = 55.68 dB

# %% [markdown]
# По сравнению с Чебышевым того же порядка:

# %%
rp = 10*np.log10(2)
worN = 1.1
w, h = sp.signal.freqs_zpk(*sp.signal.ellipap(N = 7, rp = rp, rs = rs), worN = worN)
# Eta = 10**(1/(2*7) * np.log10(1/np.abs(h[0])**2 - 1))
# w, h = sp.signal.freqs_zpk(*sp.signal.buttap(N = 7), worN = Eta)
print(f"Fading for elliptical at Wn = {worN}: {20*np.log10(np.abs(h[0])):4.1f} dB")

freqs = np.logspace(-0.5, 0.5, 1001)
w1, h1 = sp.signal.freqs_zpk(*sp.signal.ellipap(N = 7, rp = rp, rs = rs), worN = freqs)
w2, h2 = sp.signal.freqs_zpk(*sp.signal.cheb1ap(N = 7, rp = rp), worN = freqs)
cheb_filter = sp.interpolate.interp1d(w2, rs + 20*np.log10(np.abs(h2)))
chebWorN = sp.optimize.fsolve(cheb_filter, worN)[0]
print(f"Frequency for Chebyshev: {chebWorN:4.2f}")
fig = go.Figure(
    [
        go.Scatter(x = w1, y = 20*np.log10(np.abs(h1)), name = "Elliptic"),
        go.Scatter(x = w2, y = 20*np.log10(np.abs(h2)), name = "Chebyshev"),    
    ]
)
fig.add_vline(x = worN, line_dash = "dot")
fig.add_hline(y = -rs, line_dash = "dot")
fig.add_vline(x = chebWorN, line_dash = "dot", name = "Eta")
fig.update_xaxes(type = "log")
fig.show()
# Out:
# Fading for elliptical at Wn = 1.1: -55.7 dB
# Frequency for Chebyshev: 1.56
# <div>                            <div id="e6ba5bb9-69f5-4381-9efa-dd3b7cc652c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6ba5bb9-69f5-4381-9efa-dd3b7cc652c9")) {                    Plotly.newPlot(                        "e6ba5bb9-69f5-4381-9efa-dd3b7cc652c9",                        [{"name":"Elliptic","x":[0.31622776601683794,0.3169567463043491,0.31768740706497706,0.3184197521726125,0.31915378551007617,0.3198895109691398,0.3206269324505466,0.3213660538640317,0.32210687912834346,0.32284941217126356,0.32359365692962827,0.32433961734934924,0.3250872973854344,0.3258367010020088,0.32658783217233583,0.3273406948788382,0.328095293113119,0.32885163087598307,0.32960971217745777,0.3303695410368148,0.3311311214825911,0.3318944575526104,0.33265955329400454,0.333426412763235,0.3341950400261143,0.33496543915782767,0.3357376142429547,0.33651156937549076,0.3372873086588689,0.3380648362059816,0.33884415613920255,0.3396252725904084,0.3404081897010009,0.34119291162192855,0.3419794425137089,0.3427677865464504,0.34355794789987465,0.3443499307633385,0.34514373933585624,0.34593937782612194,0.3467368504525316,0.3475361614432058,0.3483373150360118,0.3491403154785861,0.34994516702835726,0.350751873952568,0.3515604405282981,0.35237087104248715,0.35318316979195696,0.35399734108343467,0.35481338923357547,0.35563131856898533,0.35645113342624424,0.3572728381519289,0.358096437102636,0.3589219346450052,0.3597493351557423,0.3605786430216424,0.3614098626396133,0.3622429984166986,0.36307805477010135,0.3639150361272071,0.3647539469256078,0.3655947916131249,0.3664375746478333,0.3672823004980847,0.36812897364253144,0.36897759857015033,0.3698281797802662,
display(Math(f"Q_{{max}}^{{Cheby}} = {Chebyshev_Qmax:.1f}"))
# Out:
# $\displaystyle Q_{max}^{Butter} = 115.3$
# $\displaystyle Q_{max}^{Cheby} = 1175.7$

# %% [markdown]
# ## 6. Преобразования эллиптических фильтров

# %% [markdown]
# Вычисляем характеристики эллиптического фильтра 7-го порядка с неравномеростью в полосе пропускания $\epsilon = 1.0$ $(rp = 3.0~dB)$ и граничной частотой $\eta = 1.5$. Максимальный уровень в полосе ослабления

# %%
rs = -ellip_stopband_level(7, 1.5)
display(Math(f"rs = {rs:4.1f}~дБ"))
# Out:
# $\displaystyle rs = 88.5~дБ$

# %%
z,p,k = sp.signal.ellipap(N = 7, rp = 10*np.log10(2), rs = rs)
freqs = np.logspace(-0.5, 0.5, 101)

w1, h1 = sp.signal.freqs_zpk(z, p, k , worN = freqs)
w2, h2 = sp.signal.freqs_zpk(*sp.signal.lp2hp_zpk(z, p, k), worN = freqs)
w3, h3 = sp.signal.freqs_zpk(*sp.signal.lp2bp_zpk(z, p, k), worN = freqs)
fig = go.Figure(
    [
        go.Scatter(x = w1, y = 20*np.log10(np.abs(h1)), name = "Lowpass"),
        go.Scatter(x = w2, y = 20*np.log10(np.abs(h2)), name = "Highpass"),
        go.Scatter(x = w3, y = 20*np.log10(np.abs(h3)), name = "Bandpass")
    ]
)
fig.update_xaxes(type = "log")
fig.show()
print(f"Zeros = {z}")
print(f"Poles = {p}")
# Out:
# <div>                            <div id="83b3b6c5-3e46-4c2f-b8be-7d59c9846a97" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83b3b6c5-3e46-4c2f-b8be-7d59c9846a97")) {                    Plotly.newPlot(                        "83b3b6c5-3e46-4c2f-b8be-7d59c9846a97",                        [{"name":"Lowpass","x":[0.31622776601683794,0.32359365692962827,0.3311311214825911,0.33884415613920255,0.3467368504525316,0.35481338923357547,0.36307805477010135,0.37153522909717257,0.3801893963205612,0.38904514499428056,0.3981071705534972,0.40738027780411273,0.4168693834703354,0.42657951880159267,0.436515832240166,0.44668359215096315,0.4570881896148751,0.46773514128719823,0.4786300923226383,0.4897788193684462,0.5011872336272722,0.5128613839913648,0.5248074602497725,0.5370317963702527,0.5495408738576245,0.5623413251903491,0.5754399373371569,0.588843655355589,0.6025595860743578,0.6165950018614821,0.6309573444801932,0.6456542290346555,0.660693448007596,0.6760829753919818,0.6918309709189365,0.7079457843841379,0.72443596007499,0.7413102413009175,0.7585775750291838,0.7762471166286917,0.7943282347242815,0.8128305161640993,0.831763771102671,0.8511380382023764,0.8709635899560807,0.8912509381337456,0.9120108393559098,0.9332543007969911,0.9549925860214359,0.9772372209558107,1.0,1.023292992280754,1.0471285480508996,1.0715193052376064,1.096478196143185,1.1220184543019636,1.1481536214968828,1.1748975549395297,1.2022644346174127,1.2302687708123814,1.258925411794167,1.2882495516931338,1.318256738556407,1.3489628825916535,1.3803842646028848,1.4125375446227544,1.4454397707459277,1.4791083881682077,1.5135612484362084,1.5488166189124815,1.5848931924611138,1.6218100973589298,1.6595869074375604,1.6982436524617444,1.7378008287493754,1.7782794100389228,1.8197008586099834,1.8620871366628675,1.9054607179632472,1.9498445997580456,1.9952623149688797,2.0417379446695296,2.0892961308540396,2.1379620895022327,2.1877616239495525,2.2387211385683394,2.290867652767773,2.344228815319922,2.3988329190194904,2.4547089156850306,2.51188643150958,2.570395782768864,2.630267991895382,2.691534803926916,2.7542287033381667,2.818382931264454,2.8840315031266055,2.9512092266663856,3.019951720402016,3.0902954325135905,3.1622776601683795],"y":[-2.6692800271494095,-2.5833996780116477,-2.4859378382763726,-2.3764575695007903,-2.2546190593803934,-2.1202246473072512,-1.9732783257224114,-1.8140634352360392,-1.6432425797247272,-1.4619835059371342,-1.272113190157941,-1.0762986432387558,-0.878245548273554,-0.6828931021423101,-0.49656417061699176,-0.3270051991383893,-0.18322665300762428,-0.07504694294398044,-0.012273558852711662,-0.003544417114683729,-0.054993932738014235,-0.1690472394109736,-0.3436904861707138,-0.5724502690258397,-0.8450749773773683,-1.1486737600753516,-1.4689609905404382,-1.791304489378519,-2.101416562218859,-2.3856672436464734,-2.6310871290793836,-2.825159755784361,-2.95550444619167,-3.009549794543423,-2.974326811501969,-2.836613436717599,-2.5839253899838304,-2.2074523309511944,-1.7092918591039041,-1.1183380197590562,-0.5193604923519882,-0.08454797804475483,-0.04404678827400663,-0.5193998312273441,-1.367372778258888,-2.269421259885878,-2.896945642284635,-2.9266976067810777,-1.9599123736410302,-0.11086905151741182,-3.0102999566398356,-10.033117881539656,-16.082197026812217,-21.196820441695596,-25.731382305044576,-29.898672295405095,-33.82773961596948,-37.60435667461864,-41.291595318960425,-44.9410013280539,-48.5996574990397,-52.31583258154704,-56.145098399636375,-60.15919674295497,-64.46217481541781,-69.22587515904596,-74.78641558908767,-82.00658628947069,-95.14961738523617,-95.42725240593052,-89.57955068629812,-88.45797342962365,-89.09159307729433,-90.97217748100009,-94.27454956132785,-100.29885831090637,-135.93746371257419,-101.29199690683342,-95. ...
# Zeros = [0.+3.0870649j  0.+1.82042775j 0.+1.52856186j 0.-3.0870649j
#  0.-1.82042775j 0.-1.52856186j]
# Poles = [-0.14579678+0.j         -0.12028955-0.49224951j -0.06859114-0.83128211j
#  -0.02102784-0.98737575j -0.12028955+0.49224951j -0.06859114+0.83128211j
#  -0.02102784+0.98737575j]

# %%
display(Latex("Измеряем добротности полюсов при разных значениях полос:"))
freqs = np.logspace(-0.5, 0.5, 1001)

result = []
traces = []
for q in [2, 5, 10]:
    bw = 1/q
    z1, p1, k1 = sp.signal.lp2bp_zpk(z, p, k, bw = bw)
    Qmax = np.max(-np.abs(p1)/np.real(p1))
    result.append([q, Qmax])
    w, h = sp.signal.freqs_zpk(z1, p1, k1 , worN = freqs)
    traces.append(go.Scatter(x = w, y = 20*np.log10(np.abs(h)), name = f"Bandpass Q = {q}"))

fig = go.Figure(traces)
fig.update_xaxes(type = "log")
fig.show()

df = pd.DataFrame(result, columns=["Q (inv. bandwidth)", "Qmax (poles)"])
display(df.style.format(precision = 0))
# Out:
# Измеряем добротности полюсов при разных значениях полос:
# <div>                            <div id="c220e686-5ce2-45d8-9f10-a656960bf766" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3dd2_level0_col0" class="col_heading level0 col0" >Q (inv. bandwidth)</th>
#       <th id="T_a3dd2_level0_col1" class="col_heading level0 col1" >Qmax (poles)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3dd2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a3dd2_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_a3dd2_row0_col1" class="data row0 col1" >196</td>
#     </tr>
#     <tr>
#       <th id="T_a3dd2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a3dd2_row1_col0" class="data row1 col0" >5</td>
#       <td id="T_a3dd2_row1_col1" class="data row1 col1" >478</td>
#     </tr>
#     <tr>
#       <th id="T_a3dd2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a3dd2_row2_col0" class="data row2 col0" >10</td>
#       <td id="T_a3dd2_row2_col1" class="data row2 col1" >952</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 7. Полосовые фильтры радиоприемников

# %% [markdown]
# Селективность эллиптического фильтра 7-го порядка с ослаблением 80 дБ в полосе подавления:

# %%
eta = ellip_stopband_freq(7, 80)
display(Math(f"\eta = {eta:4.2f}"))
# Out:
# $\displaystyle \eta = 1.36$

# %% [markdown]
# Оценим порядок фильтра Чебышева для достижения той же селективности:

# %%
result = []
for N in range(5, 15):
    w, h = sp.signal.freqs_zpk(*sp.signal.cheb1ap(N, rp = 10*np.log10(2)), worN = eta)
    result.append([N, -20*np.log10(np.abs(h[0]))])
df = pd.DataFrame(result, columns = ["Order", "Fade Level [dB]"])
display(df.style.format(precision = 1))
# Out:
# <style type="text/css">
# </style>
# <table id="T_f7094">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7094_level0_col0" class="col_heading level0 col0" >Order</th>
#       <th id="T_f7094_level0_col1" class="col_heading level0 col1" >Fade Level [dB]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7094_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f7094_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_f7094_row0_col1" class="data row0 col1" >29.8</td>
#     </tr>
#     <tr>
#       <th id="T_f7094_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f7094_row1_col0" class="data row1 col0" >6</td>
#       <td id="T_f7094_row1_col1" class="data row1 col1" >37.0</td>
#     </tr>
#     <tr>
#       <th id="T_f7094_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f7094_row2_col0" class="data row2 col0" >7</td>
#       <td id="T_f7094_row2_col1" class="data row2 col1" >44.2</td>
#     </tr>
#     <tr>
#       <th id="T_f7094_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f7094_row3_col0" class="data row3 col0" >8</td>
#       <td id="T_f7094_row3_col1" class="data row3 col1" >51.3</td>
#     </tr>
#     <tr>
#       <th id="T_f7094_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f7094_row4_col0" class="data row4 col0" >9</td>
#       <td id="T_f7094_row4_col1" class="data row4 col1" >58.5</td>
#     </tr>
#     <tr>
#       <th id="T_f7094_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f7094_row5_col0" class="data row5 col0" >10</td>
#       <td id="T_f7094_row5_col1" class="data row5 col1" >65.7</td>
#     </tr>
#     <tr>
#       <th id="T_f7094_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f7094_row6_col0" class="data row6 col0" >11</td>
#       <td id="T_f7094_row6_col1" class="data row6 col1" >72.8</td>
#     </tr>
#     <tr>
#       <th id="T_f7094_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f7094_row7_col0" class="data row7 col0" >12</td>
#       <td id="T_f7094_row7_col1" class="data row7 col1" >80.0</td>
#     </tr>
#     <tr>
#       <th id="T_f7094_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f7094_row8_col0" class="data row8 col0" >13</td>
#       <td id="T_f7094_row8_col1" class="data row8 col1" >87.2</td>
#     </tr>
#     <tr>
#       <th id="T_f7094_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f7094_row9_col0" class="data row9 col0" >14</td>
#       <td id="T_f7094_row9_col1" class="data row9 col1" >94.3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# По таблице определяем $N_{cheby} = 12$

# %% [markdown]
# Определим максимальные добротности полюсов полосовых фильтров.

# %% [markdown]
# Для фильтра Чебышева:

# %%
z,p,k = sp.signal.lp2bp_zpk(*sp.signal.cheb1ap(N = 12, rp = 10*np.log10(2)), bw = 1/20)
ChebyshevQmax = np.max(-np.abs(p)/np.real(p))
print(f"Qmax = {ChebyshevQmax:4.0f}")
# Out:
# Qmax = 4170

# %% [markdown]
# Для эллиптического фильтра:

# %%
z, p, k = sp.signal.lp2bp_zpk(*sp.signal.ellipap(N = 7, rp = 10*np.log10(2), rs = 80), bw = 1/20)
EllipQmax = np.max(-np.abs(p)/np.real(p))
print(f"Qmax = {EllipQmax:4.0f}")
# Out:
# Qmax = 2099
